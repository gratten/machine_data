# %% [markdown]
# #### generate import file for machine table

# %%
# home
path = 'C:\\Users\\gratten\\Documents\\python\\projects\\machine_data'

# work
# path = 'C:\\Users\\WDG1DCR\Desktop\\my_projects\\web\\machine_data'

import os
os.chdir(f'{path}\\notebooks')

# %%
import pandas as pd

# %%
fileName = 'endload_serialnums'

# %%
xl = pd.ExcelFile(f'source_data/{fileName}.xlsx')
df = xl.parse('Enterprise')

# %%
df.shape
# Out:
# (46, 11)

# %%
machine_columns = ['project',
                   'prodline',
                   'serialnum',
                   'customer',
                   'description']

# %%
df_machine = pd.DataFrame(columns=machine_columns)

# %%
serialnums = []

for i in df["SERIAL #"]:
    serialnums.append(i)

# %%
# limit to x10 machines for testing
# serialnums = serialnums[:10]

# %%
df_machine['serialnum'] = serialnums

# %%
df_machine.head()
# Out:
#   project prodline     serialnum customer description
# 0     NaN      NaN  ENT-ABOC-101      NaN         NaN
# 1     NaN      NaN       ENT-103      NaN         NaN
# 2     NaN      NaN       ENT-104      NaN         NaN
# 3     NaN      NaN       ENT-105      NaN         NaN
# 4     NaN      NaN    ENT-OC-108      NaN         NaN

# %%
df_trimmed = df[df['SERIAL #'] == df_machine['serialnum'][0]]
# df_trimmed.iloc[:,0].to_string(index=False)

# %%
for i in range(len(df_machine['serialnum'])):
    df_trimmed = df[df['SERIAL #'] == df_machine['serialnum'][i]]
    
    machine_project = df_trimmed.iloc[:,0].to_string(index=False)
    machine_project = machine_project.replace('/n', '')
    
    df_machine['project'][i] = machine_project
    df_machine['prodline'][i] = 'Enterprise'
    df_machine['customer'][i] = df_trimmed.iloc[:,2].to_string(index=False)
    df_machine['description'][i] = df_trimmed.iloc[:,3].to_string(index=False)
# Out:
#  HS5062
#
#  HS5077
#
#  HS5097
#
#  HS5103
#
#  HS5120
#
#  HS5120
#
#  HS5120
#
#  HS5121
#
#  HS5122
#
#  HS5141
#
#  HS5143
#
#  HS5146
#
#  HS5150
#
#  HS5150
#
#  HS5150
#
#  HS5160
#
#  HS5160
#
#  HS5161
#
#  HS5161
#
#  HS5162
#
#  HS5163
#
#  HS5190
#
#  HS5192
#
#  HS5192
#
#  HS5193
#
#  HS5194
#
#  HS5200
#
#  HS5207
#
#  HS5208
#
#  HS5211
#
#  HS5220
#
#  HS5222
#
#  HS5223
#
#  HS5223
#
#  HS5230
#
#  HS5235
#
#  HS5239
#
#  HS5245
#
#  HS5245
#
#  HS5245
#
#  HS5246
#
#  HS5247
#
#  HS5252
#
#  HS5267
#
#  HS5271
#
#  HS5281

# %%
df_machine.head(50)
# Out:
#      project    prodline     serialnum                            customer  \
# 0     HS5062  Enterprise  ENT-ABOC-101                         SUGAR FOODS
# 1     HS5077  Enterprise       ENT-103                              NESTLE
# 2     HS5097  Enterprise       ENT-104                           FURLANI'S
# 3     HS5103  Enterprise       ENT-105                        JOHNSONVILLE
# 4     HS5120  Enterprise    ENT-OC-108   BENCHMARK AUTOMATION / FEHR FOODS
# 5     HS5120  Enterprise    ENT-OC-109   BENCHMARK AUTOMATION / FEHR FOODS
# 6     HS5120  Enterprise    ENT-OC-110   BENCHMARK AUTOMATION / FEHR FOODS
# 7     HS5121  Enterprise  ENT-AB-106                        SARGENTO FOODS
# 8     HS5122  Enterprise       ENT-111                           HILLSHIRE
# 9     HS5141  Enterprise  ENT-ABOC-102                ADVANCE PEIRRE FOODS
# 10    HS5143  Enterprise       ENT-112                         TYSON FOODS
# 11    HS5146  Enterprise    ENT-OC-113                                 ARI
# 12    HS5150  Enterprise    ENT-AB-114                      SARGENTO FOODS
# 13    HS5150  Enterprise    ENT-AB-115                      SARGENTO FOODS
# 14    HS5150  Enterprise    ENT-AB-116                      SARGENTO FOODS
# 15    HS5160  Enterprise       ENT-117                             SCHWANS
# 16    HS5160  Enterprise       ENT-118                             SCHWANS
# 17    HS5161  Enterprise       ENT-119                             SCHWANS
# 18    HS5161  Enterprise       ENT-120                             SCHWANS
# 19    HS5162  Enterprise       ENT-121                 MAPLEHURST BAKERIES
# 20    HS5163  Enterprise       ENT-122                             SCHWANS
# 21    HS5190  Enterprise       ENT-124                             SCHWANS
# 22    HS5192  Enterprise       ENT-125                             SCHWANS
# 23    HS5192  Enterprise       ENT-126                             SCHWANS
# 24    HS5193  Enterprise       ENT-123                     TABLE TALK PIES
# 25    HS5194  Enterprise       ENT-127                         TYSON FOODS
# 26    HS5200  Enterprise    ENT-AB-128                      SARGENTO FOODS
# 27    HS5207  Enterprise    ENT-AB-129                       RICH PRODUCTS
# 28    HS5208  Enterprise    ENT-AB-130                       RICH PRODUCTS
# 29    HS5211  Enterprise       ENT-131                 HARRY'S FRESH FOODS
# 30    HS5220  Enterprise       ENT-132                        COOPER FARMS
# 31    HS5222  Enterprise       ENT-133                       REQUEST FOODS
# 32    HS5223  Enterprise    ENT-AB-134                      SARGENTO FOODS
# 33    HS5223  Enterprise    ENT-AB-135                      SARGENTO FOODS
# 34    HS5230  Enterprise       ENT-136                          TABLE TALK
# 35    HS5235  Enterprise       ENT-137                    TYSON(HILLSHIRE)
# 36    HS5239  Enterprise       ENT-138                          BOSCH PACB
# 37    HS5245  Enterprise       ENT-108                        ABIMAR FOODS
# 38    HS5245  Enterprise       ENT-109                        ABIMAR FOODS
# 39    HS5245  Enterprise       ENT-110                        ABIMAR FOODS
# 40    HS5246  Enterprise       ENT-140                      OVERHILL FARMS
# 41    HS5247  Enterprise       ENT-141                      OVERHILL FARMS
# 42   HS5252   Enterprise       ENT-142                     TABLE TALK PIES
# 43    HS5267  Enterprise       ENT-143                               TYSON
# 44    HS5271  Enterprise       ENT-144                         KRAFT HEINZ
# 45    HS5281  Enterprise  ENT-ABOC-145              Quaity Food Processors
#
#                                                                                                                                                                                                                     description
# 0                                                                                                                                                                                     MID-RANGE, 12" FLIGHTS, ARTICLE BUCKETS
# 1                                                                                                                                                                                        ENTERPRISE H, 9" FLIGHTS, PIC INFEED
# 2                                                                                                                                                ENTERPRISE, 9" FLIGHTS, PIC INFEED WITH 90" (8 FT) PIC EXTENSION, ENTERPRISE
# 3                                                                                                                                        ENTERPRISE, 12" FLIGHTS, PIC INFEED,  LASER MESH GUARDS & TRAC-I, RIGHT ANGLE TRANSFER
# 4                                                                                                                                                   ENTERPRISE, 9" FLIGHTS, PIC INFEED, OPP HAND WITH 90" (8 FT) EXTENSION PIC
# 5                                                                                                                                                   ENTERPRISE, 9" FLIGHTS, PIC INFEED, OPP HAND WITH 90" (8 FT) EXTENSION PIC
# 6                                                                                                                                                   ENTERPRISE, 9" FLIGHTS, PIC INFEED, OPP HAND WITH 90" (8 FT) EXTENSION PIC
# 7    ENTERPRISE, 9" FLIGHTS, FIXED ARTICLE BUCKET INFEED & FIXED ARTICLE BUCKET INFEED, 7.5 FT  & 9.0 FT                                                          ENTERPRISE, 9" FLIGHTS, FIXED ARTICLE BUCKET INFEED, OPP HAND
# 8                                                                                                                ENTERPRISE END LOAD CARTONER 9" INCH PITCH STANDARD PRODUCT INFEED CONVEYOR.\n(1) WSIPTU PRODUCT TRANSFER UNIT
# 9                                                                                                                                                                        ENTERPRISE, 12" MECHANICAL ASSEMBLIES, ARTICLE BUCKET
# 10                                                                                                           ENTERPRISE, 12" FLIGHTS, PIC INFEED, POLY CHAIN DRIVE, OPP HAND WITH  4 FT PIC EXTENSION, ENTERPRISE,  12" PITCH
# 11                                                                                                                                                                                         ENTERPRISE, 12" FLIGHTS, PIC INFEED
# 12                                                                                                                                                      ENTERPRISE, 9" FLIGHTS, FIXED ARTICLE BUCKET INFEED, UPGRADED GEARBOXES
# 13                                                                                                                                                      ENTERPRISE, 9" FLIGHTS, FIXED ARTICLE BUCKET INFEED, UPGRADED GEARBOXES
# 14                                                                                                                                                      ENTERPRISE, 9" FLIGHTS, FIXED ARTICLE BUCKET INFEED, UPGRADED GEARBOXES
# 15                                                                                                               ENTERPRISE, 12" FLIGHTS, PIC INFEED,  SEMI OCTAGON CARTON MODS WITH WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT
# 16                                                                                                               ENTERPRISE, 12" FLIGHTS, PIC INFEED,  SEMI OCTAGON CARTON MODS WITH WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT
# 17                                                                                                                   ENTERPRISE, 12" FLIGHTS, PIC INFEED,  SEMI OCTAGON CARTON MODS WITH WSIPTU, IN-LINE STYLE PRODUCT INFEED
# 18                                                                                                                   ENTERPRISE, 12" FLIGHTS, PIC INFEED,  SEMI OCTAGON CARTON MODS WITH WSIPTU, IN-LINE STYLE PRODUCT INFEED
# 19                                                                                                                                 ENTERPRISE, 15" FLIGHTS, PIC INFEED, OPP HAND / WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT
# 20                                                                                                                   ENTERPRISE, 12" FLIGHTS, PIC INFEED,  SEMI OCTAGON CARTON MOD / WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT
# 21                                                                                                                                                                                                                          NaN
# 22                                                                                                                                              ENTERPRISE, 9" FLIGHTS, PIC INFEED / WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT
# 23                                                                                                                                              ENTERPRISE, 9" FLIGHTS, PIC INFEED / WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT
# 24                                                                                                           ENTERPRISE H, 9" FLIGHTS, PIC INFEED  7 SERVO DRIVE / SIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT, 9" W/EASY CLEAN
# 25                                                                                                                       ENTERPRISE, 12" FLIGHTS, PIC INFEED / SIPTU, IN-LINE STYLE PRODUCT INFEED UNIT, 12" W/EASY CLEAN MODS
# 26                                                                                                         ENTERPRISE, 9" FLIGHTS, FIXED ARTICLE BUCKET INFEED,  SEW GEARBOXES WITH FIXED ARTICLE BUCKET INFEED, 7.5 FT & 9.00"
# 27                                                                                                                                                                                 ENTERPRISE H, 9" FLIGHTS, FIXED AB INFEED,
# 28                                                                                                                                                          ENTERPRISE H, 9" FLIGHTS, FIXED AB INFEED,  W 7.5 FT PIC EXTENSION
# 29                                                                                                                                ENTERPRISE, STD. HAND, 9" FLIGHTS, PIC INFEED 7 SERVO DRIVE / W PIC 27" EXTENSION, ENTERPRISE
# 30                                                                                                                                                                               ENTERPRISE, 12" FLIGHTS, PIC INFEED 5" WIDTH
# 31                          ENTERPRISE H, 9" FLIGHTS, PIC INFEED 7 SERVO DRIVE, WAIST LEVEL HOPPER  / WSIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT EXTENDED CORRECTION BELTS / RTS TOP LEVEL MECH ASSY, 8-HD CW, FOR ENTERPRISE
# 32                                                                 9" FLIGHTS, FIXED AB INFEED, NEW GEARBOX MTG LIBERTY GLUE SYSTEM  & ENTERPRISE, 9" FLIGHTS, FIXED AB INFEED, NEW GEARBOX MTG LIBERTY GLUE SYSTEM, OPP HAND
# 33                                                                 9" FLIGHTS, FIXED AB INFEED, NEW GEARBOX MTG LIBERTY GLUE SYSTEM  & ENTERPRISE, 9" FLIGHTS, FIXED AB INFEED, NEW GEARBOX MTG LIBERTY GLUE SYSTEM, OPP HAND
# 34                                                                                                     ENTERPRISE H, 9" FLIGHTS, PIC INFEED, 2/2018 7 SERVO DRIVE / SIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT, 9" W/EASY CLEAN
# 35                                                                                                                ENTERPRISE H 9" FLIGHTS, PIC INFEED, 7 SERVO DRIVE WASTE LEVEL HOPPER, MESH GUARDS  / HIGH SPEED SCREW INFEED
# 36                                                                                        ENTERPRISE H, 9" FLIGHTS, PIC INFEED, 2/2018 7 SERVO DRIVE WITH PIC 4 FT (49.5") EXTENSION, ENTERPRISE, 9" PITCH / WSIPTU-129, PN29
# 37                                                                                                                                                                                                                          NaN
# 38                                                                                                                                                                                                                          NaN
# 39                                                                                                                                                                                                                          NaN
# 40                                                                                                                                       ENTERPRISE H, 9" FLIGHTS, PIC INFEED, STD, OPP HAND / FARMS, HIGH SPEED SCREW INFEED
# 41                                                                                                                                                                    ENTERPRISE, 15" FLIGHTS, PIC INFEED  / TRACI-109 INFEED
# 42                                                                                   ENTERPRISE H, 9" FLIGHTS, PIC INFEED, 2/2018 7 SERVO DRIVE / SIPTU, IN-LINE STYLE PRODUCT INFEED  UNIT, 9" W/EASY CLEAN MODS, WSIPTU-131
# 43                                                                                                                                                                                  ENTERPRISE H, 9" FLIGHTS, FIXED AB INFEED
# 44                                                                                                                                        NTERPRISE HIGH SPEED CARTONER, OPP HAND, WAIST LEVEL HOPPER / HIGH SPEED SCREW INFEED
# 45                                                                                                                                       ENTERPRISE, 9" FIXED AB, BACON MODS (8' hopper, no tuckers, LS film plowing, 5/8" WOO)

# %%
# required so that long strings are not truncated when exported to csv
pd.set_option("display.max_colwidth", 10000)

# %%
os.chdir(f'{path}\\external')
df_machine.to_csv('endload.csv', sep=';', index=False, header=False)
